# %%
from fuzzywuzzy import process, fuzz
import pandas as pd

def batch_match_anonymized_to_identified(anonymized_df, identified_df, match_columns, threshold=60, 
                                         anonymized_file=None, anonymized_sheet=None):
    """
    Perform batched matching of anonymized rows to identified rows for large datasets.
    
    :param anonymized_df: DataFrame with anonymized data.
    :param identified_df: DataFrame with identified data, including source metadata.
    :param match_columns: List of columns to use for matching.
    :param threshold: Minimum matching score to consider a match valid.
    :param anonymized_file: The file name of the anonymized data.
    :param anonymized_sheet: The sheet name of the anonymized data.
    :return: DataFrame with matched results and metadata for tracking.
    """
    anonymized_df = anonymized_df.copy()
    identified_df = identified_df.copy()
    
    # Create concatenated strings for matching
    anonymized_df['match_key'] = anonymized_df[match_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)
    identified_df['match_key'] = identified_df[match_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)
    
    # Create dictionary for faster lookups
    identified_keys = identified_df['match_key'].to_list()
    identified_lookup = {key: idx for idx, key in enumerate(identified_keys)}
    
    # Initialize results
    matches = []
    for index, row in anonymized_df.iterrows():
        key = row['match_key']
        best_match = process.extractOne(key, identified_keys, scorer=fuzz.token_set_ratio)
        
        if best_match and best_match[1] >= threshold:
            matched_idx = identified_lookup[best_match[0]]
            matched_row = identified_df.iloc[matched_idx]
            matches.append({
                'Anonymized_Index': index,
                'Anonymized_Key': key,
                'Matched_Key': best_match[0],
                'Match_Score': best_match[1],
                'Matched_Row_Index_Excel': matched_row['Original_Row_Index'],  # Use the stored original row index
                'Matched_Row_Details': matched_row.to_dict(),
                'Anonymized_File_Name': anonymized_file,
                'Anonymized_Sheet_Name': anonymized_sheet,
                'Matched_File_Name': matched_row['Source_File_Name'],
                'Matched_Sheet_Name': matched_row['Source_Sheet_Name'],
            })
    
    return pd.DataFrame(matches)

# Load Excel files
file_jan = "11201查處名單.xlsx"
file_feb = "11202查處名單.xlsx"
file_mar = "11203查處名單.xlsx"

# Specify sheets for anonymized and identified data
anonymized_sheets = {"Jan": "表A名單1", "Feb": "表A名單1", "Mar": "表A名單1"}
identified_sheets = {"Jan": "表A名單2", "Feb": "表A名單2", "Mar": "表A名單2"}

# Load identified data with source metadata and original row index
identified_dfs = []
for file_name, sheet_name in zip([file_jan, file_feb, file_mar], 
                                 [identified_sheets["Jan"], identified_sheets["Feb"], identified_sheets["Mar"]]):
    df = pd.read_excel(file_name, sheet_name=sheet_name)
    df['Source_File_Name'] = file_name
    df['Source_Sheet_Name'] = sheet_name
    df['Original_Row_Index'] = df.index + 2  # Add 2 to align with Excel row indexing (1-based, includes header)
    identified_dfs.append(df)

# Combine identified data
combined_identified_data = pd.concat(identified_dfs, ignore_index=True)

# Load anonymized data for January
data_jan_anonymized = pd.read_excel(file_jan, sheet_name=anonymized_sheets["Jan"])

# Perform matching
match_columns = ['地號', '廠址']
results_jan = batch_match_anonymized_to_identified(
    data_jan_anonymized,
    combined_identified_data,
    match_columns,
    threshold=60,
    anonymized_file=file_jan,
    anonymized_sheet=anonymized_sheets["Jan"]
)

#
#     Match_Score  Matched_Row_Index_Excel  \
# 0            61                        3
# 1            61                        3
# 2            77                      410
# 3            60                      115
# 4            67                      126
# 5            60                      202
# 6            60                       18
# 7            60                       89
# 8            60                      311
# 9            60                      117
# 10           60                      115
# 11           60                       89
# 12           60                      311
# 13           60                      103
# 14           60                      103
# 15           63                      423
# 16           60                       18
# 17           65                      166
# 18           65                      380
# 19           65                      380
# 20           74                      423
# 21           60                      154
# 22           60                      115
# 23           61                      228
# 24           61                      211
# 25           60                      202
# 26           60                      207
# 27           70                      250
# 28           60                      311
# 29           70                      250
# 30           60                      311
# 31           60                      311
# 32           65                      283
# 33           71                      302
# 34           60                      103
# 35           65                      256
# 36           65                      394
# 37           65                      256
# 38           67                      426
# 39           67                      126
# 40           60                      311
# 41           62                      260
# 42           67                      406
# 43           60                      311
# 44           67                      381
#
#                                   Matched_Row_Details Anonymized_File_Name  \
# 0   {'序號': 2, '縣市': '臺中市', '工廠名稱': '無', '市、鎮、村、里':...       11201查處名單.xlsx
# 1   {'序號': 2, '縣市': '臺中市', '工廠名稱': '無', '市、鎮、村、里':...       11201查處名單.xlsx
# 2   {'序號': 409, '縣市': '彰化縣', '工廠名稱': '無市招', '市、鎮、村...       11201查處名單.xlsx
# 3   {'序號': 114, '縣市': '新北市', '工廠名稱': '頂隆機械廠', '市、鎮...       11201查處名單.xlsx
# 4   {'序號': 125, '縣市': '新北市', '工廠名稱': '大漢食品企業社', '市...       11201查處名單.xlsx
# 5   {'序號': 201, '縣市': '臺中市', '工廠名稱': '綠野奇木藝品社', '市...       11201查處名單.xlsx
# 6   {'序號': 17, '縣市': '新北市', '工廠名稱': '北貿紙品有限公司', '市...       11201查處名單.xlsx
# 7   {'序號': 88, '縣市': '新北市', '工廠名稱': '文炬工業股份有限公司', ...       11201查處名單.xlsx
# 8   {'序號': 310, '縣市': '臺南市', '工廠名稱': '台南市玉井區農會', '...       11201查處名單.xlsx
# 9   {'序號': 116, '縣市': '新北市', '工廠名稱': '天香豆腐工廠', '市、...       11201查處名單.xlsx
# 10  {'序號': 114, '縣市': '新北市', '工廠名稱': '頂隆機械廠', '市、鎮...       11201查處名單.xlsx
# 11  {'序號': 88, '縣市': '新北市', '工廠名稱': '文炬工業股份有限公司', ...       11201查處名單.xlsx
# 12  {'序號': 310, '縣市': '臺南市', '工廠名稱': '台南市玉井區農會', '...       11201查處名單.xlsx
# 13  {'序號': 102, '縣市': '新北市', '工廠名稱': '艾麗而有限公司
# (皇太后...       11201查處名單.xlsx
# 14  {'序號': 102, '縣市': '新北市', '工廠名稱': '艾麗而有限公司
# (皇太后...       11201查處名單.xlsx
# 15  {'序號': 422, '縣市': '桃園市', '工廠名稱': '沅勝精密機械有限公司',...       11201查處名單.xlsx
# 16  {'序號': 17, '縣市': '新北市', '工廠名稱': '北貿紙品有限公司', '市...       11201查處名單.xlsx
# 17  {'序號': 165, '縣市': '桃園市', '工廠名稱': '普昱企業社', '市、鎮...       11201查處名單.xlsx
# 18  {'序號': 379, '縣市': '桃園市', '工廠名稱': '德州塗料有限公司', '...       11201查處名單.xlsx
# 19  {'序號': 379, '縣市': '桃園市', '工廠名稱': '德州塗料有限公司', '...       11201查處名單.xlsx
# 20  {'序號': 422, '縣市': '桃園市', '工廠名稱': '沅勝精密機械有限公司',...       11201查處名單.xlsx
# 21  {'序號': 153, '縣市': '桃園市', '工廠名稱': '晟耀光電科技股份有限公司...       11201查處名單.xlsx
# 22  {'序號': 114, '縣市': '新北市', '工廠名稱': '頂隆機械廠', '市、鎮...       11201查處名單.xlsx
# 23  {'序號': 227, '縣市': '臺中市', '工廠名稱': '永伸昶雷射科技有限公司'...       11201查處名單.xlsx
# 24  {'序號': 210, '縣市': '臺中市', '工廠名稱': '真優美倉儲設備有限公司'...       11201查處名單.xlsx
# 25  {'序號': 201, '縣市': '臺中市', '工廠名稱': '綠野奇木藝品社', '市...       11201查處名單.xlsx
# 26  {'序號': 206, '縣市': '臺中市', '工廠名稱': '華旭光電股份有限公司',...       11201查處名單.xlsx
# 27  {'序號': 249, '縣市': '臺南市', '工廠名稱': '茂鑫企業社', '市、鎮...       11201查處名單.xlsx
# 28  {'序號': 310, '縣市': '臺南市', '工廠名稱': '台南市玉井區農會', '...       11201查處名單.xlsx
# 29  {'序號': 249, '縣市': '臺南市', '工廠名稱': '茂鑫企業社', '市、鎮...       11201查處名單.xlsx
# 30  {'序號': 310, '縣市': '臺南市', '工廠名稱': '台南市玉井區農會', '...       11201查處名單.xlsx
# 31  {'序號': 310, '縣市': '臺南市', '工廠名稱': '台南市玉井區農會', '...       11201查處名單.xlsx
# 32  {'序號': 282, '縣市': '臺南市', '工廠名稱': '德記木業行', '市、鎮...       11201查處名單.xlsx
# 33  {'序號': 301, '縣市': '臺南市', '工廠名稱': '花漾窗簾', '市、鎮、...       11201查處名單.xlsx
# 34  {'序號': 102, '縣市': '新北市', '工廠名稱': '艾麗而有限公司
# (皇太后...       11201查處名單.xlsx
# 35  {'序號': 255, '縣市': '臺南市', '工廠名稱': '圓通速遞', '市、鎮、...       11201查處名單.xlsx
# 36  {'序號': 393, '縣市': '臺南市', '工廠名稱': '承誼機電有限公司', '...       11201查處名單.xlsx
# 37  {'序號': 255, '縣市': '臺南市', '工廠名稱': '圓通速遞', '市、鎮、...       11201查處名單.xlsx
# 38  {'序號': 425, '縣市': '彰化縣', '工廠名稱': '金達億有限公司', '市...       11201查處名單.xlsx
# 39  {'序號': 125, '縣市': '新北市', '工廠名稱': '大漢食品企業社', '市...       11201查處名單.xlsx
# 40  {'序號': 310, '縣市': '臺南市', '工廠名稱': '台南市玉井區農會', '...       11201查處名單.xlsx
# 41  {'序號': 259, '縣市': '臺南市', '工廠名稱': '無廠名', '市、鎮、村...       11201查處名單.xlsx
# 42  {'序號': 405, '縣市': '苗栗縣', '工廠名稱': '吉晟企業社', '市、鎮...       11201查處名單.xlsx
# 43  {'序號': 310, '縣市': '臺南市', '工廠名稱': '台南市玉井區農會', '...       11201查處名單.xlsx
# 44  {'序號': 380, '縣市': '臺中市', '工廠名稱': '原金興業社', '市、鎮...       11201查處名單.xlsx
#
#    Anonymized_Sheet_Name Matched_File_Name Matched_Sheet_Name
# 0                  表A名單1    11203查處名單.xlsx              表A名單2
# 1                  表A名單1    11203查處名單.xlsx              表A名單2
# 2                  表A名單1    11203查處名單.xlsx              表A名單2
# 3                  表A名單1    11203查處名單.xlsx              表A名單2
# 4                  表A名單1    11203查處名單.xlsx              表A名單2
# 5                  表A名單1    11203查處名單.xlsx              表A名單2
# 6                  表A名單1    11203查處名單.xlsx              表A名單2
# 7                  表A名單1    11203查處名單.xlsx              表A名單2
# 8                  表A名單1    11203查處名單.xlsx              表A名單2
# 9                  表A名單1    11203查處名單.xlsx              表A名單2
# 10                 表A名單1    11203查處名單.xlsx              表A名單2
# 11                 表A名單1    11203查處名單.xlsx              表A名單2
# 12                 表A名單1    11203查處名單.xlsx              表A名單2
# 13                 表A名單1    11203查處名單.xlsx              表A名單2
# 14                 表A名單1    11203查處名單.xlsx              表A名單2
# 15                 表A名單1    11203查處名單.xlsx              表A名單2
# 16                 表A名單1    11203查處名單.xlsx              表A名單2
# 17                 表A名單1    11203查處名單.xlsx              表A名單2
# 18                 表A名單1    11203查處名單.xlsx              表A名單2
# 19                 表A名單1    11203查處名單.xlsx              表A名單2
# 20                 表A名單1    11203查處名單.xlsx              表A名單2
# 21                 表A名單1    11203查處名單.xlsx              表A名單2
# 22                 表A名單1    11203查處名單.xlsx              表A名單2
# 23                 表A名單1    11203查處名單.xlsx              表A名單2
# 24                 表A名單1    11203查處名單.xlsx              表A名單2
# 25                 表A名單1    11203查處名單.xlsx              表A名單2
# 26                 表A名單1    11203查處名單.xlsx              表A名單2
# 27                 表A名單1    11203查處名單.xlsx              表A名單2
# 28                 表A名單1    11203查處名單.xlsx              表A名單2
# 29                 表A名單1    11203查處名單.xlsx              表A名單2
# 30                 表A名單1    11203查處名單.xlsx              表A名單2
# 31                 表A名單1    11203查處名單.xlsx              表A名單2
# 32                 表A名單1    11203查處名單.xlsx              表A名單2
# 33                 表A名單1    11203查處名單.xlsx              表A名單2
# 34                 表A名單1    11203查處名單.xlsx              表A名單2
# 35                 表A名單1    11203查處名單.xlsx              表A名單2
# 36                 表A名單1    11203查處名單.xlsx              表A名單2
# 37                 表A名單1    11203查處名單.xlsx              表A名單2
# 38                 表A名單1    11203查處名單.xlsx              表A名單2
# 39                 表A名單1    11203查處名單.xlsx              表A名單2
# 40                 表A名單1    11203查處名單.xlsx              表A名單2
# 41                 表A名單1    11203查處名單.xlsx              表A名單2
# 42                 表A名單1    11203查處名單.xlsx              表A名單2
# 43                 表A名單1    11203查處名單.xlsx              表A名單2
# 44                 表A名單1    11203查處名單.xlsx              表A名單2
